# %% [markdown]
# # NLP - Tokenizacion
# # Bienvenido

# %%
import pandas as pd
import pickle, os
import fasttext

# APPS Reputación Digital
from app.tokenizadores import tokenizador_i
# Out:
# 2023-10-31 22:35:58.322668: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-31 22:35:59.268277: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#!pip install fasttext


##model_path = f'{os.getcwd()}/models/cc.es.300.bin'
##model = fasttext.load_model(model_path)

# %%
df = pd.read_csv("RD-comentarios-facebook.csv")
df
# Out:
#                                                content sentiment_i  \
# 0                                      lala es tu papa    negative
# 1                                   eduardo gobernador     neutral
# 2    vidal gonzalez das pena con tu comentario te g...    negative
# 3    como juegan con los ciudadanos , parecen niños...    positive
# 4    bertha angulo eso lo emos dicho amiga pero ay ...    positive
# ..                                                 ...         ...
# 455             habla de que usa el dinero para gastos     neutral
# 456  que nos explique el que quiere ser gober preci...     neutral
# 457  juan carlos garcia ruiz y ahi queda pero con l...    negative
# 458  juan carlos garcia ruiz efectivamente!!no tien...    negative
# 459  juan carlos garcia ruiz con el narco como lope...     neutral
#
#      score_sentiment_i emotions_6_max_label  \
# 0             0.899070                anger
# 1             0.389714                anger
# ...

# %%
tokens = tokenizador_i.main("rd-comentarios-facebook.csv")
tokens
# Out:
# /home/jovyan/Análisis de Contenido/app/main/data_preparation.py:120: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   hash_series = pd.Series(hash_dict)
# checkpoint 1: DataFrame previo a la tokenizacion
# Tokenizando: 460it [00:00, 34219.78it/s]
# checkpoint 2: tokenizacion finalizada
# programa finalizado de forma exitosa
#                                                content usuarios_mencionados  \
# 0                                      lala es tu papa                  NaN
# 1                                   eduardo gobernador                  NaN
# 2    vidal gonzalez das pena con tu comentario te g...                  NaN
# 3    como juegan con los ciudadanos parecen niños c...                  NaN
# 4    bertha angulo eso lo emos dicho amiga pero ay ...                  NaN
# ..                                                 ...                  ...
# ...
