# %% [markdown]
# # NLP - Tokenizacion
# # Bienvenido

# %%
import pandas as pd
import pickle, os
import fasttext

# APPS Reputación Digital
from app.tokenizadores import tokenizador_i

# %%
#!pip install fasttext


##model_path = f'{os.getcwd()}/models/cc.es.300.bin'
##model = fasttext.load_model(model_path)

# %%
df = pd.read_csv("RD-comentarios-facebook.csv")
df
# Out:
#                                               content emojis i_nombre_propios  \
# 0   gracias crack sos unico leo mil gracia por ase...     []               []
# 1   porque sean famosos no van a poner limites es ...     []               []
# 2   una genia antonela asi se educa a los hijos fe...     []               []
# 3   esta bien a los chicos hay que ponerle en su l...     []               []
# 4   no es cosa de otro mundo che q tiene de malo p...     []               []
# 5   esta muy bien de reprender a su hijo ponerlo e...     []               []
# 6                              david villaangela iacc     []               []
# 7                 asi se esduca sin importar el lugar     []               []
# 8   eso es educar a un niño con un reto es suficiente     []               []
# 9   eso es educarlos enseñarles que hay que respet...     []               []
# 10                                           muy bien     []               []
# 11                                      esta perfecto     []               []
# 12                   muy bien que le yamo la atencion     []               []
# 13  hay que ver cada pavadas abiendo tantas cosas ...     []               []
# 14  mirta gola habiendo tanto para comentar vienes...     []               []
# 15  si estuviera aca en argentina ya estarian las ...     []               []
# 16  excelente el dìa de mañana el hom bre serà el ...     []               []
# 17  excelente madre la planta se enderiesa de chiq...     []               []
# 18  muy educados siempre diferencian cada ocasion ...     []               []
# 19                            excelente madre y padre     []               []
# 20  una excelente mami corregirlo siempre a sus hijos     []               []
# 21  ahhh y es un niño no porque sea el hijo de mes...     []               []
# 22  muy bien a los hijos hay que ponerles limites ...     []               []
# 23         marcos enrique casoli los golpes no educan     []               []
# 24  frida kalo a veces si una tunda bien dada a ti...     []               []
# 25           pobres chicos fue largo se portan rebien     []               []
# 26  asies asi es una mama ahiq ponerle limistes an...     []               []
# 27                       antonela no me quemeee ja ja     []               []
# 28  ese ciro lo retan en todos los eventos se vio ...     []               []
# 29                         amanda n belottini gracias     []               []
# 30                           correccion como debe ser     []               []
# 31  bien echo a veces un tironcito a tiempo es un ...     []               []
# 32  me regañaban me ponian en penitencia lipiando ...     []               []
# 33     ayy no la mataron a ella con esa foto jajajaja     []               []
# 34  como toda mama argentina jajaja de mi epoca ja...     []               []
# 35  thiago es un niño no un jarron adelante santi ...     []               []
# 36  pero que le importa a los medios lo que hace l...     []               []
# 37  sergio fabian gargiulo es que hoy es noticia v...     []               []
# 38                           son re argentinos jajaja     []               []
# 39  interesante si lo hacia l gante hub estado mal...     []               []
#
#                                              tokens_i  \
# 0   ['gracias', 'unico', 'gracia', 'aserlo', 'arge...
# 1   ['porque', 'famosos', 'limites', 'cualquiera',...
# 2   ['genia', 'antonela', 'educa', 'felicitaciones...
# 3                               ['chicos', 'ponerle']
# 4   ['malo', 'peor', 'pega', 'fuerte', 'dios', 'ha...
# 5               ['reprender', 'ponerlo', 'antonella']
# 6                    ['david', 'villaangela', 'iacc']
# 7                              ['esduca', 'importar']
# 8            ['educar', 'niño', 'reto', 'suficiente']
# 9   ['educarlos', 'enseñarles', 'respetar', 'escuc...
# 10                                            ['muy']
# 11                                       ['perfecto']
# 12                        ['muy', 'yamo', 'atencion']
# 13  ['pavadas', 'abiendo', 'tantas', 'señora', 'me...
# 14  ['mirta', 'gola', 'habiendo', 'comentar', 'vie...
# 15  ['estuviera', 'aca', 'argentina', 'estarian', ...
# 16  ['excelente', 'dìa', 'serà', 'reflejo', 'hogar...
# 17             ['excelente', 'enderiesa', 'chiquita']
# 18  ['muy', 'educados', 'diferencian', 'ocasion', ...
# 19                                      ['excelente']
# 20                             ['mami', 'corregirlo']
# 21  ['ahhh', 'niño', 'messi', 'portar', 'inquieto'...
# 22          ['muy', 'ponerles', 'limites', 'nalgada']
# 23  ['marcos', 'enrique', 'casoli', 'golpes', 'edu...
# 24  ['frida', 'kalo', 'tunda', 'dada', 'despues', ...
# 25           ['pobres', 'chicos', 'portan', 'rebien']
# 26  ['asies', 'ahiq', 'ponerle', 'limistes', 'anue...
# 27                            ['antonela', 'quemeee']
# 28     ['ciro', 'retan', 'vio', 'clarito', 'reclamo']
# 29                            ['amanda', 'belottini']
# 30                                     ['correccion']
# 31                              ['bien', 'tironcito']
# 32  ['regañaban', 'ponian', 'penitencia', 'lipiand...
# 33                     ['ayy', 'mataron', 'jajajaja']
# 34         ['argentina', 'jajaja', 'epoca', 'jajaja']
# 35  ['thiago', 'niño', 'jarron', 'adelante', 'sant...
# 36                      ['pero', 'importa', 'chicos']
# 37  ['sergio', 'fabian', 'gargiulo', 'noticia', 'c...
# 38                           ['argentinos', 'jajaja']
# 39                           ['interesante', 'gante']
#
#                                             tokens_ii sentiment_i  \
# 0   ['crack', 'sos', 'leo', 'mil', 'por', 'tan', '...     neutral
# 1   ['sean', 'van', 'poner', 'una', 'mama', 'como'...    positive
# 2                      ['una', 'asi', 'los', 'hijos']    negative
# 3               ['esta', 'bien', 'los', 'hay', 'que']    negative
# 4   ['cosa', 'otro', 'mundo', 'che', 'tiene', 'ser...     neutral
# 5   ['esta', 'muy', 'bien', 'hijo', 'lugar', 'una'...     neutral
# 6                                                  []    negative
# 7                                      ['asi', 'sin']    negative
# 8                                      ['eso', 'con']     neutral
# 9              ['eso', 'que', 'hay', 'que', 'estaba']    negative
# 10                                                 []     neutral
# 11                                           ['esta']    positive
# 12                                    ['bien', 'que']    negative
# 13  ['hay', 'que', 'ver', 'cada', 'cosas', 'mas', ...    negative
# 14                 ['tanto', 'para', 'este', 'sitio']     neutral
# 15                  ['las', 'sociales', 'las', 'una']     neutral
# 16  ['mañana', 'hom', 'bre', 'del', 'que', 'mayor'...    negative
# 17                                ['madre', 'planta']    negative
# 18                                ['siempre', 'cada']     neutral
# 19                                          ['madre']    negative
# 20             ['una', 'excelente', 'siempre', 'sus']     neutral
# 21  ['porque', 'sea', 'hijo', 'puede', 'mal', 'ser...    positive
# 22  ['bien', 'los', 'hijos', 'hay', 'que', 'veces'...    negative
# 23                                            ['los']    negative
# 24  ['veces', 'una', 'bien', 'tiempo', 'ayuda', 'q...     neutral
# 25                                   ['fue', 'largo']     neutral
# 26                             ['asi', 'una', 'mama']    negative
# 27                                                 []    negative
# 28                 ['ese', 'todos', 'los', 'eventos']     neutral
# 29                                                 []    negative
# 30                                   ['como', 'debe']     neutral
# 31      ['echo', 'veces', 'tiempo', 'hombre', 'bien']    positive
# 32                                   ['dijo', 'nada']    negative
# 33                     ['ella', 'con', 'esa', 'foto']    negative
# 34                           ['como', 'toda', 'mama']     neutral
# 35                                    ['todo', 'que']     neutral
# 36  ['que', 'los', 'medios', 'que', 'hace', 'madre...    negative
# 37  ['que', 'hoy', 'ver', 'que', 'una', 'madre', '...    negative
# 38                                            ['son']     neutral
# 39                  ['hacia', 'hub', 'estado', 'mal']    negative
#
#     score_sentiment_i
# 0            0.629372
# 1            0.790913
# 2            0.932987
# 3            0.527084
# 4            0.548975
# 5            0.575018
# 6            0.582334
# 7            0.908021
# 8            0.569827
# 9            0.900712
# 10           0.629372
# 11           0.790913
# 12           0.932987
# 13           0.527084
# 14           0.548975
# 15           0.575018
# 16           0.582334
# 17           0.908021
# 18           0.569827
# 19           0.900712
# 20           0.629372
# 21           0.790913
# 22           0.932987
# 23           0.527084
# 24           0.548975
# 25           0.575018
# 26           0.582334
# 27           0.908021
# 28           0.569827
# 29           0.900712
# 30           0.629372
# 31           0.790913
# 32           0.932987
# 33           0.527084
# 34           0.548975
# 35           0.575018
# 36           0.582334
# 37           0.908021
# 38           0.569827
# 39           0.900712

# %%
tokens = tokenizador_i.main("milei.csv")
tokens
# Out:
# Tokenizando: 3000it [00:00, 76873.19it/s]
#                                                 content  \
# 0     javier milei diciendo lo que todos sabemos y q...
# 1     tiene la palabra javier milei sobre derechos h...
# 2     javier milei diciendo lo que todos sabemos y q...
# 3     javier milei no fueron 30 000 los desaparecido...
# 4     javier milei no fueron 30 000 los desaparecido...
# ...                                                 ...
# 2995  la educacion en cordoba es un modelo para tras...
# 2996                     milei sin dudas gana el debate
# 2997  que debate espectacular estas haciendo en tu c...
# 2998  agustin sos el mejor novio del mundo  gracias ...
# 2999  no fueron 30 000 en los 70 hubo una guerra neg...
#
#                                    usuarios_mencionados  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2995                            [@JSchiaretti, @JMilei]
# 2996        [@diegobranca, @SergioMassa, @PatoBullrich]
# 2997                                          [@JMilei]
# 2998  [@AgustinLaje, @NickyMarquez1, @JMilei, @PatoB...
# 2999                                          [@JMilei]
#
#                                 hashtags  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                          [#Debate2023]
# 4                          [#Debate2023]
# ...                                  ...
# 2995                                 NaN
# 2996                                 NaN
# 2997                                 NaN
# 2998                                 NaN
# 2999  [#Debate2023, #DebatePresidencial]
#
#                                                   links  emojis  \
# 0                             [https://t.co/aNLBbXtFPv]      []
# 1                             [https://t.co/Qf8JJdbOAF]      []
# 2                             [https://t.co/aNLBbXtFPv]      []
# 3     [https://t.co/kS99hDepY1, https://t.co/oRL5nZ8...      []
# 4     [https://t.co/kS99hDepY1, https://t.co/oRL5nZ8...      []
# ...                                                 ...     ...
# 2995                                                NaN      []
# 2996                                                NaN      []
# 2997                                                NaN      []
# 2998                                                NaN  [🥰, ❤]
# 2999                                                NaN      []
#
#                                        i_nombre_propios  \
# 0                                       [Javier, Milei]
# 1     [Tiene, Javier, Milei, Derechos, Humanos, Conv...
# 2                                       [Javier, Milei]
# 3                                       [Javier, Milei]
# 4                                       [Javier, Milei]
# ...                                                 ...
# 2995                       [Córdoba, Alguien, Escondió]
# 2996                                            [Milei]
# 2997                                                 []
# 2998                                          [Agustín]
# 2999                                                 []
#
#                                                tokens_i  \
# 0     [javier, milei, diciendo, sabemos, politicos, ...
# 1     [tiene, javier, milei, humanos, convivencia, d...
# 2     [javier, milei, diciendo, sabemos, politicos, ...
# 3       [javier, milei, 30, 000, desaparecidos, 8, 753]
# 4       [javier, milei, 30, 000, desaparecidos, 8, 753]
# ...                                                 ...
# 2995  [educacion, cordoba, trasladar, entendio, educ...
# 2996                               [milei, dudas, gana]
# 2997   [espectacular, cumpleaños, regalar, presidencia]
# 2998                     [agustin, novio, presidencial]
# 2999   [30, 000, 70, hubo, negacionista, contemporaneo]
#
#                                               tokens_ii
# 0     [que, todos, que, los, son, mas, los, mas, mie...
# 1                            [palabra, sobre, derechos]
# 2     [que, todos, que, los, son, mas, los, mas, mie...
# 3                                 [fueron, los, fueron]
# 4                                 [fueron, los, fueron]
# ...                                                 ...
# 2995  [modelo, para, pais, alguien, que, dijo, sobre...
# 2996                                              [sin]
# 2997              [que, debate, estas, haciendo, vamos]
# 2998  [sos, mejor, del, mundo, gracias, por, ver, de...
# 2999                         [fueron, los, una, guerra]
#
# [3000 rows x 8 columns]
