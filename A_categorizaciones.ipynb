# %% [markdown]
# ### Categorizacion automatica: 1 modelo de Transformers
#
# Se ejecuta M4_similarity. Clásificación por similaridad respecto a los tópicos ingresados por el usuario.
#
# **Los tópicos se definen en la celda "User input"**

# %%
##  INPUT USUARIO  ##  INPUT USUARIO  ##  ##  INPUT USUARIO  ##  INPUT USUARIO  ##

archivo_lectura = "categoria-cholula-facebook.csv"

topicos = ["politica", "sociedad", "culturales", "salud", "deportes", "naturaleza", "seguridad", "audiovisual", "ciencia", "economia", "educacion"]


twitter = False
facebook = True
instagram = False

# %%
# PROGRAMA PRINCIPAL
if sum([twitter, facebook, instagram]) != 1:
    print("Elija un solo filtro")
    exit()

# Librerias de Python
import pickle, sys, os, datetime
import pandas as pd
import ipyaggrid

# APPs
from app.main.data_feed import main as leer_csv
from app.time_series import TimeSeries
from app.tokenizadores import tokenizador_i
from app.m4_similarity import M4_similarity


# Librerías personales
from app.main.data_feed import main as leer_csv
from tools.feed import procesar_file_csv, data_info
from tools.facebook import clean_facebook_comments
from tools.intagram import clean_instagram_comments

# %%
nombre, archivo = procesar_file_csv(archivo_lectura)

df = leer_csv(archivo, verbose=True)

if not twitter:
    if facebook:
        batch = clean_facebook_comments(df.content.to_list())
    elif instagram:
        batch = clean_instagram_comments(df.content.to_list())
    df = pd.DataFrame(batch, columns=["content"])

first_8 = "- " + "\n- ".join([t.replace("\n","") for t in df.head(8).content.to_list()])
print(f"Primeros 8 registros:\n{first_8}")
# Out:
#     Resumen de la apertura de .csv:
#
#           columna  Nan  pct_nan   dtype  count  pct_reg  count_unique
# 0  @timestamp    0      0.0  object   1211    100.0           912
# 1      author    0      0.0  object   1211    100.0            22
# 2       agent    0      0.0  object   1211    100.0             1
# 3     content    0      0.0  object   1211    100.0          1087
# 4    page_url    0      0.0  object   1211    100.0          1209
#
# Primeros 8 registros:
# - * Mientras asegura permanecerá al frente del Senado de la República hasta el 24 de diciembrePUEBLA.- Alejandro Armenta Mier, coordinador de la Defensa de la Cuarta Transformación en Puebla, permanecerá al frente del Senado de la República hasta el 24 de diciembre, ya que al siguiente día iniciará la precampaña electoral.
# - ¡Feliz lunes! Este es el clima esperado en Puebla para este inicio de semana ☁️
# - Comenzamos la semana con #HechosPrimeraLínea 📺
# - CHOLULA.- Hola Compañeros, deseo se encuentren bien. Mi nombre es Vicky y soy alcohólica. Llegué al Grupo sin Dios y resentida con la vida por todo lo que había pasado, soy hija de un alcohólico y, por lo tanto, resentida con mi padre. El alcohol estuvo siempre presente conmigo desde niña.
# - Seguro más de una vez te lo has preguntado, ¿Qué pasa si tiro aceite al drenaje? 🫧♒️
# - * El gobierno encabezado por Paola Angon arranca la actualización de la señalética para personas con discapacidad, implementando el símbolo de accesibilidad universal, promovido por la ONUCHOLULA.- Al encabezar el inicio de la sustitución de señalética para personas con discapacidad en el municipio, usando el símbolo de accesibilidad universal -que de acuerdo con información de la Organización
# - “Otoño”Por: Sandra Liliana MARTÍNEZ ZANELLAARKANSAS, USA.-  En esta época que la naturaleza cambia de colores: naranja, amarillo y rojizo. Las hojas de los árboles empiezan a caer pero el árbol sigue de pie, no será tan fácil derrumbarlo con raíces fuertes en el suelo.
# - * El percance ocurrió tras una discusión entre dos personas que no se conocían, en el Cole's Flea Market en la zona de Pearland y las víctimas fueron trasladadas a hospitalesTEXAS.- Dos niños y otras tres personas fueron baleadas en un mercado en Texas el domingo por la noche, y un niño murió después en el hospital, según la policía.

# %%
try:
    path = TimeSeries.main(archivo_lectura, conservar_duplicados=True) ## default: eliminar repetidos
    with open(path, "rb") as f:
        df = pickle.load(f)
        df = df.reset_index(drop=True)
except:
    # print("Error en el procesamiento de TimeSeries")
    # print('Comprobar la existencia de "@timestamp" o "date" dentro de las columnas')
    print("Continuando ejecución...\n")

dftk = tokenizador_i.main_df(df.copy())

df["content"] = dftk["content"]
dftk = dftk.drop(columns=["content"])

df = pd.concat([df, dftk], axis=1)
df.name = nombre



print()
# display(df.head(8))
first_8 = "- " + "\n- ".join([t.replace("\n","") for t in df.head(8).content.to_list()])
print(f"Primeros 8 registros:\n{first_8}")
data_info(df)
# Out:
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_usuarios.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(hashtag, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_hashtags.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# c:\Users\Agustin\Desktop\RD\Octubre\RD_APP\tools\deteccion_https.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[idx] = data[idx].replace(mencion, '').strip()
# Tokenizando: 1211it [00:00, 52610.18it/s]
# Primeros 8 registros:
# - mientras asegura permanecera al frente del senado de la republica hasta el 24 de diciembre puebla alejandro armenta mier coordinador de la defensa de la cuarta transformacion en puebla permanecera al frente del senado de la republica hasta el 24 de diciembre ya que al siguiente dia iniciara la precampaña electoral
# - feliz lunes este es el clima esperado en puebla para este inicio de semana
# - comenzamos la semana con
# - cholula hola compañeros deseo se encuentren bien mi nombre es vicky y soy alcoholica llegue al grupo sin dios y resentida con la vida por todo lo que habia pasado soy hija de un alcoholico y por lo tanto resentida con mi padre el alcohol estuvo siempre presente conmigo desde niña
# - seguro mas de una vez te lo has preguntado que pasa si tiro aceite al drenaje
# - el gobierno encabezado por paola angon arranca la actualizacion de la señaletica para personas con discapacidad implementando el simbolo de accesibilidad universal promovido por la onu cholula al encabezar el inicio de la sustitucion de señaletica para personas con discapacidad en el municipio usando el simbolo de accesibilidad universal que de acuerdo con informacion de la organizacion
# - otoño por sandra liliana martinez zanella arkansas usa en esta epoca que la naturaleza cambia de colores naranja amarillo y rojizo las hojas de los arboles empiezan a caer pero el arbol sigue de pie no sera tan facil derrumbarlo con raices fuertes en el suelo
# - el percance ocurrio tras una discusion entre dos personas que no se conocian en el cole s flea market en la zona de pearland y las victimas fueron trasladadas a hospitales texas dos niños y otras tres personas fueron baleadas en un mercado en texas el domingo por la noche y un niño murio despues en el hospital segun la policia
#                  columna   Nan  pct_nan           dtype  count  pct_reg  \
# 0             @timestamp     0     0.00          object   1211   100.00
# 1                 author     0     0.00          object   1211   100.00
# 2                  agent     0     0.00          object   1211   100.00
# 3                content     0     0.00          object   1211   100.00
# 4               page_url     0     0.00          object   1211   100.00
# 5               datetime     0     0.00  datetime64[ns]   1211   100.00
# 6               date_str     0     0.00          object   1211   100.00
# 7               time_str     0     0.00          object   1211   100.00
# 8   usuarios_mencionados  1191    98.35          object     20     1.65
# 9               hashtags   803    66.31          object    408    33.69
# 10                 links  1136    93.81          object     75     6.19
# 11                emojis     0     0.00          object   1211   100.00
# 12      i_nombre_propios     0     0.00          object   1211   100.00
# 13              tokens_i     0     0.00          object   1211   100.00
# 14             tokens_ii     0     0.00          object   1211   100.00
#
#     count_unique
# 0            912
# 1             22
# 2              1
# 3           1075
# 4           1209
# 5            912
# 6              4
# 7            660
# 8             12
# 9            170
# 10            18
# 11           403
# 12           802
# 13          1068
# 14          1017

# %%
## FILTRO PARA DIFERENCIAR PUBLICACIONES VS COMENTARIOS

# %%
## IMPLEMTACION DEL MODELO M4
df = df.drop_duplicates(subset=["content"])
df = M4_similarity.main_df(df, topicos, max_workers=8)
df.name = nombre
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# INICIANDO PREDICCIONES
# Procesando batch numero: 1
# Procesando batch numero: 2
# Procesando batch numero: 3
# Procesando batch numero: 4
# Procesando batch numero: 5
# Procesando batch numero: 6
# Procesando batch numero: 7
# Procesando batch numero: 8
# Procesando batch numero: 9
# Transformers Nº 3 finalizado
# Transformers Nº 8 finalizado
# Transformers Nº 2 finalizado
# Transformers Nº 7 finalizado
# Transformers Nº 0 finalizado
# Transformers Nº 4 finalizado
# Transformers Nº 5 finalizado
# Transformers Nº 1 finalizado
# Transformers Nº 6 finalizado
# PREDICCIONES COMPLETADAS
# tiempo de ejecución: 3393.944795846939 segs
# Ajuste de las features finalizada.

# %%
# Umbrales:
umbral_probabilidad = 0.3
umbral_distancia = 0.5

# Filtro de probabilidad
low_score_mask = pd.DataFrame(df.score_similarity_i.to_list()).iloc[:, 0] < umbral_probabilidad

# Muestra para corregir las categorizaciones
df_correccion = df[low_score_mask]
# Muestra para análisis
df = df[~low_score_mask]

# DataFrame auxiliares
df_scores = pd.DataFrame(df.score_similarity_i.to_list())
df_labels = pd.DataFrame(df.similarity_i.to_list())
mask_2da_etiqueta = (1- (df_scores.iloc[:, 0] - df_scores.iloc[:, 1]) / (df_scores.iloc[:, 0] + df_scores.iloc[:, 1])) > umbral_distancia


df["max_2_similarity_i"] = df_labels[mask_2da_etiqueta].iloc[:, 1]
df.max_2_similarity_i = df.max_2_similarity_i.fillna("otros")
# Out:
# C:\Users\Agustin\AppData\Local\Temp\ipykernel_7736\3540686666.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_scores = pd.DataFrame(df.score_similarity_i.to_list())[~low_score_mask]
# C:\Users\Agustin\AppData\Local\Temp\ipykernel_7736\3540686666.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_labels = pd.DataFrame(df.similarity_i.to_list())[~low_score_mask]

# %%
## NO EJECUTAR ESTA CELDA HASTA QUE ESTEN IMPLEMENTADOS LOS FILTROS DE LOW_SCORE Y SEGUNDA_ETIQUETA

## DESCARGA DE ARCHIVOS
## project_root/Z_{nombre}/backup.pkl
## project_root/Z_{nombre}/porcentajes.txt
## project_root/Z_{nombre}/{archivo}


output_dir = os.getcwd()
output_dir = os.path.join(output_dir, f"Z_{nombre}")
os.makedirs(output_dir, exist_ok=True)


with open(os.path.join(output_dir, "backup-analisis.pkl"), "wb") as f:
    df.name = nombre
    pickle.dump(df, f)

with open(os.path.join(output_dir, "backup-correccion.pkl"), "wb") as f:
    df_correccion.name = nombre
    pickle.dump(df_correccion, f)


df.to_csv(os.path.join(output_dir, archivo), index=False)


porcentajes = (df.max_similarity_i.value_counts()/df.max_similarity_i.value_counts().sum() *100).round(1).astype(str) + " %"
with open(os.path.join(output_dir, "porcentajes.txt"), "w") as f:
    f.write(str(porcentajes))

porcentajes_2 = (df.max_2_similarity_i.value_counts()/df.max_2_similarity_i.value_counts().sum() *100).round(1).astype(str) + " %"
with open(os.path.join(output_dir, "porcentajes_2.txt"), "w") as f:
    f.write(str(porcentajes_2))

# %%
df.head(1)
df.head(1).columns
df[["content", "max_similarity_i", "max_2_similarity_i", "similarity_i", "score_similarity_i"]]
# Out:
#                                                 content max_similarity_i  \
# 0     mientras asegura permanecera al frente del sen...         politica
# 1     feliz lunes este es el clima esperado en puebl...    medioambiente
# 2                              comenzamos la semana con         economia
# 3     cholula hola compañeros deseo se encuentren bi...         sociedad
# 4     seguro mas de una vez te lo has preguntado que...    medioambiente
# ...                                                 ...              ...
# 1067  tras el paso del huracan otis la sep detecto 3...      audiovisual
# 1068  el operativo sorpresa en la 16 poniente dejo c...    medioambiente
# 1069  en la comunidad de xaltianguis acapulco habita...      audiovisual
# 1070  no sabes si tienes pagos pendientes aqui te da...         economia
# 1071  el cuerpo del periodista fue hallado dentro de...        seguridad
#
#      max_2_similarity_i                                       similarity_i  \
# 0             seguridad  [politica, seguridad, sociedad, economia, cult...
# 1                 otros  [medioambiente, audiovisual, economia, ciencia...
# 2              sociedad  [economia, sociedad, ciencia, seguridad, salud...
# 3            culturales  [sociedad, culturales, audiovisual, economia, ...
# 4             seguridad  [medioambiente, seguridad, ciencia, audiovisua...
# ...                 ...                                                ...
# 1067              otros  [audiovisual, educacion, sociedad, ciencia, se...
# 1068              otros  [medioambiente, seguridad, sociedad, audiovisu...
# 1069              otros  [audiovisual, medioambiente, sociedad, cultura...
# 1070              otros  [economia, audiovisual, sociedad, medioambient...
# 1071              otros  [seguridad, audiovisual, sociedad, salud, econ...
#
#                                      score_similarity_i
# 0     [0.9989986419677734, 0.9966900944709778, 0.605...
# 1     [0.9751686453819275, 0.13746343553066254, 0.04...
# 2     [0.6061476469039917, 0.5776166915893555, 0.510...
# 3     [0.8490357995033264, 0.6944432854652405, 0.114...
# 4     [0.8928437232971191, 0.42611584067344666, 0.41...
# ...                                                 ...
# 1067  [0.9991481304168701, 0.9973485469818115, 0.288...
# 1068  [0.9915850758552551, 0.9756875038146973, 0.194...
# 1069  [0.999313235282898, 0.9830295443534851, 0.9767...
# 1070  [0.4271853566169739, 0.049520161002874374, 0.0...
# 1071  [0.7948466539382935, 0.042511068284511566, 0.0...
#
# [988 rows x 5 columns]
