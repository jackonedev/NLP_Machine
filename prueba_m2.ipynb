# %% [markdown]
# ## Vamos a levantar el objeto obtenido de la predicción del m2
#
# clasificador de emociones
#
# scores de procesamiento:
#
# 1257 registros, 3 minutos de ejecución, en CPU.

# %%
import pandas as pd
import pickle

# %%
with open("M2_OUTPUT.pickle", "rb") as f:
    predictions = pickle.load(f)

# %%
predictions
# Out:
# [[{'label': 'joy', 'score': 0.9978883862495422},
#   {'label': 'fear', 'score': 0.0007302645826712251},
#   {'label': 'love', 'score': 0.00042076274985447526},
#   {'label': 'sadness', 'score': 0.00035041800583712757},
#   {'label': 'anger', 'score': 0.0003101005859207362},
#   {'label': 'surprise', 'score': 0.00030003374558873475}],
#  [{'label': 'joy', 'score': 0.8523598909378052},
#   {'label': 'love', 'score': 0.13321690261363983},
#   {'label': 'anger', 'score': 0.00867919996380806},
#   {'label': 'sadness', 'score': 0.003416219027712941},
#   {'label': 'surprise', 'score': 0.00198486284352839},
#   {'label': 'fear', 'score': 0.00034305904409848154}],
#  [{'label': 'anger', 'score': 0.9497283697128296},
#   {'label': 'sadness', 'score': 0.02419125847518444},
#   {'label': 'joy', 'score': 0.018667902797460556},
#   {'label': 'love', 'score': 0.004709454718977213},
#   {'label': 'surprise', 'score': 0.0017718193121254444},
#   {'label': 'fear', 'score': 0.0009312230977229774}],
# ...
